# %% [markdown]
# # **Scraping eBay for sold listings of Rolex "Root Beer GMT-Master II" watches**

# %% [markdown]
# ### ***Importing necessary modules for script below***

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import pandasql as ps

# %% [markdown]
# ### ***Defining function to access ebay search URL***

# %% [markdown]
# ##### *eBay searches model number and filters by sold items, brand-new and pre-owned conditions, and "Rolex" brand*

# %%
model_number = '126711CHNR'

# %%
def scrape_data(model_number):
    url = f"https://www.ebay.com/sch/i.html?_dcat=31387&_fsrp=1&rt=nc&_from=R40&LH_AV=1&LH_Complete=1&_ipg=240&LH_ItemCondition=3000%7C1000&LH_Sold=1&_nkw={model_number}&_sacat=0&Brand=Rolex"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# %% [markdown]
# ### ***Defining function to parse data from HTML of ebay search URL, arranged into preferred dictionary format***

# %%
def parse_data(soup):
    products_list = []
    results = soup.find_all('div', attrs={'class': 's-item__wrapper clearfix'})
    for item in results[2:243]:
        sold_listings = {
            'title': item.find('span', {'role': 'heading'}).text,
            'condition': item.find('span', {'class': 'SECONDARY_INFO'}).text,
            'sold_price_USD': item.find('span', {'class': 's-item__price'}).text,
            'sold_date': item.find('span', {'class': 's-item__caption--signal POSITIVE'}).text,
            'listing_url': item.find('a', {'class': 's-item__link'})['href']
        }
        products_list.append(sold_listings)
    return products_list

# %% [markdown]
# ### ***Defining function to save parsed data into CSV file in library***

# %%
def save_csv(products_list, model_number):
    products_df = pd.DataFrame(products_list)
    products_df.to_csv('Rolex_' + model_number + '_sold_listings.csv', index=False)
    print('Rolex_' + model_number + '_sold_listings saved to CSV file')
    return

# %% [markdown]
# ### ***Plugging variables into defined functions to create our customized CSV file of scraped eBay data***

# %%
soup = scrape_data(model_number)
products_list = parse_data(soup)
save_csv(products_list, model_number)
# Out:
# Rolex_126711CHNR_sold_listings saved to CSV file

# %% [markdown]
# # *Cleaning and formatting our CSV data*

# %% [markdown]
# ### ***Reviewing our main dataframe via custom CSV file***

# %% [markdown]
# ##### *Checking for null values and improper field data types*

# %%
df = pd.read_csv(f'Rolex_{model_number}_sold_listings.csv')

# %%
df.head()
# Out:
#                                                title  condition  \
# 0  Rolex GMT-Master II 126711CHNR Root Beer Rose ...  Brand New
# 1  Rolex GMT-Master II 126711CHNR Root Beer Two-T...  Pre-Owned
# 2  Rolex GMT-Master II "Root Beer" Automatic Men'...  Brand New
# 3  MINT PAPERS Rolex GMT-Master II Two-Tone Root ...  Pre-Owned
# 4  Rolex GMT-Master II Rootbeer Full Set Watch 12...  Pre-Owned
#
#   sold_price_USD           sold_date  \
# 0     $20,387.00   Sold  Jun 3, 2024
# 1     $18,393.81  Sold  May 31, 2024
# 2     $21,525.00   Sold  Jan 6, 2023
# 3     $18,493.81  Sold  May 14, 2024
# 4     $17,750.00  Sold  May 13, 2024
#
#                                          listing_url
# 0  https://www.ebay.com/itm/126486174406?hash=ite...
# 1  https://www.ebay.com/itm/186449439850?hash=ite...
# 2  https://www.ebay.com/itm/155065004433?epid=140...
# 3  https://www.ebay.com/itm/156190246811?hash=ite...
# 4  https://www.ebay.com/itm/285852231447?hash=ite...

# %%
df.isnull().any()
# Out:
# title             False
# condition         False
# sold_price_USD    False
# sold_date         False
# listing_url       False
# dtype: bool

# %%
df.dtypes
# Out:
# title             object
# condition         object
# sold_price_USD    object
# sold_date         object
# listing_url       object
# dtype: object

# %% [markdown]
# ##### *Correcting field data types and formats, adding necessary fields to the dataframe*

# %%
df['sold_date'] = df['sold_date'].str.strip('Sold ')
df['sold_date'] = pd.to_datetime(df['sold_date'], format='%b %d, %Y')

# %%
df['sold_price_USD'] = df['sold_price_USD'].str.replace('$','').str.replace(',','').astype(float)

# %%
df.insert(1, 'model_number', model_number)

# %% [markdown]
# ### ***Reviewing CSV file of additional Rolex data(sourced from Kaggle)***

# %% [markdown]
# ##### *Checking for null values and improper field data types*

# %%
rolex_retail = pd.read_csv('Prezzi_Originali_puliti.csv', sep=';')

# %%
rolex_retail.head()
# Out:
#    Size Reference          Collection                   Description      RRP  \
# 0    40    116900            Air King                 Standard Dial   6180.0
# 1    40  116500LN  Cosmograph Daytona                 Standard Dial  12600.0
# 2    40    116503  Cosmograph Daytona                 Standard Dial  16800.0
# 3    40    116503  Cosmograph Daytona                  Diamond Dial  18720.0
# 4    40    116503  Cosmograph Daytona  Mother of Pearl Diamond Dial  21360.0
#
#                                Complication
# 0                                       NaN
# 1  Chronograph, Small Seconds, Stop Seconds
# 2                Chronograph, Small Seconds
# 3                Chronograph, Small Seconds
# 4                Chronograph, Small Seconds

# %%
rolex_retail.dtypes
# Out:
# Size             int64
# Reference       object
# Collection      object
# Description     object
# RRP             object
# Complication    object
# dtype: object

# %% [markdown]
# ##### *Correcting field data types and formats, adding necessary fields to this dataframe*

# %%
rolex_retail[rolex_retail['Reference'] == model_number]
# Out:
#      Size   Reference     Collection    Description      RRP Complication
# 152    40  126711CHNR  GMT-Master II  Standard Dial  14220.0    Date, GMT

# %%
rolex_retail['RRP'] = pd.to_numeric(rolex_retail['RRP'], errors='coerce').astype(float).round(2)
rolex_retail = rolex_retail.rename(columns={'RRP':'retail_GBP'})

# %%
GBP_USD_exch_rate = requests.get("https://api.frankfurter.app/latest?amount=1&from=gbp&to=usd").json()['rates']['USD']
rolex_retail['retail_USD'] = rolex_retail['retail_GBP'].multiply(GBP_USD_exch_rate).round(2)

# %% [markdown]
# # **Using SQL for additional formatting and data exploration**

# %% [markdown]
# ### ***Joining the two tables into our main dataframe***

# %%
join_query = '''
    SELECT * 
    FROM df
    LEFT JOIN rolex_retail ON df.model_number = rolex_retail.Reference
    '''

df = ps.sqldf(join_query, locals())

# %% [markdown]
# ### ***Reviewing updated dataframe***

# %%
df.head()
# Out:
#                                                title model_number  condition  \
# 0  Rolex GMT-Master II 126711CHNR Root Beer Rose ...   126711CHNR  Brand New
# 1  Rolex GMT-Master II 126711CHNR Root Beer Two-T...   126711CHNR  Pre-Owned
# 2  Rolex GMT-Master II "Root Beer" Automatic Men'...   126711CHNR  Brand New
# 3  MINT PAPERS Rolex GMT-Master II Two-Tone Root ...   126711CHNR  Pre-Owned
# 4  Rolex GMT-Master II Rootbeer Full Set Watch 12...   126711CHNR  Pre-Owned
#
#    sold_price_USD                   sold_date  \
# 0        20387.00  2024-06-03 00:00:00.000000
# 1        18393.81  2024-05-31 00:00:00.000000
# 2        21525.00  2023-01-06 00:00:00.000000
# 3        18493.81  2024-05-14 00:00:00.000000
# 4        17750.00  2024-05-13 00:00:00.000000
#
#                                          listing_url  Size   Reference  \
# 0  https://www.ebay.com/itm/126486174406?hash=ite...    40  126711CHNR
# 1  https://www.ebay.com/itm/186449439850?hash=ite...    40  126711CHNR
# 2  https://www.ebay.com/itm/155065004433?epid=140...    40  126711CHNR
# 3  https://www.ebay.com/itm/156190246811?hash=ite...    40  126711CHNR
# 4  https://www.ebay.com/itm/285852231447?hash=ite...    40  126711CHNR
#
#       Collection    Description  retail_GBP Complication  retail_USD
# 0  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 1  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 2  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 3  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 4  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14

# %% [markdown]
# ##### *Adding necessary fields to the dataframe*

# %%
profit_query_update_df = '''
    SELECT *, sold_price_USD - retail_USD profit_USD, ((sold_price_USD / retail_USD)-1) * 100 growth_pct
    FROM df
    '''

df = ps.sqldf(profit_query_update_df, locals())
df
# Out:
#                                                 title model_number  condition  \
# 0   Rolex GMT-Master II 126711CHNR Root Beer Rose ...   126711CHNR  Brand New
# 1   Rolex GMT-Master II 126711CHNR Root Beer Two-T...   126711CHNR  Pre-Owned
# 2   Rolex GMT-Master II "Root Beer" Automatic Men'...   126711CHNR  Brand New
# 3   MINT PAPERS Rolex GMT-Master II Two-Tone Root ...   126711CHNR  Pre-Owned
# 4   Rolex GMT-Master II Rootbeer Full Set Watch 12...   126711CHNR  Pre-Owned
# 5   MINT 2021 PAPERS Rolex GMT-Master II 18K Gold ...   126711CHNR  Pre-Owned
# 6   MINT 2021 PAPERS Rolex GMT-Master II 18K Gold ...   126711CHNR  Pre-Owned
# 7   2022 PAPERS Rolex GMT-Master II Two-Tone Root ...   126711CHNR  Pre-Owned
# 8   NEW APRIL 2024 Rolex GMT-Master II Two-Tone Ro...   126711CHNR  Brand New
# 9   Rolex GMT-Master II 126711CHNR Root Beer Unwor...   126711CHNR  Brand New
# 10  Rolex GMT-Master II 126711CHNR Root Beer UNWOR...   126711CHNR  Brand New
# 11  Rolex GMT-Master II Root Beer Wristwatch 12671...   126711CHNR  Pre-Owned
# 12  NEW FEB 2024 PAPERS Rolex GMT-Master II 18K Go...   126711CHNR  Brand New
# 13  2022 Rolex GMT-Master II Two-Tone ROOT BEER Ro...   126711CHNR  Pre-Owned
# 14  2022 Unworn Unsized Rolex GMT Master II Two To...   126711CHNR  Brand New
# 15  MINT 2021 PAPERS Rolex GMT-Master II 18K Gold ...   126711CHNR  Pre-Owned
# 16  MINT 2021 PAPERS Rolex GMT-Master II 18K Gold ...   126711CHNR  Pre-Owned
# 17  Rolex GMT-Master II Root Beer 126711CHNR 18k R...   126711CHNR  Pre-Owned
# 18  Rolex 126711CHNR 40 Mm GMT-Master II Root Beer...   126711CHNR  Pre-Owned
# 19  ROLEX GMT Master II 126711CHNR Stainless Steel...   126711CHNR  Pre-Owned
#
#     sold_price_USD                   sold_date  \
# 0         20387.00  2024-06-03 00:00:00.000000
# 1         18393.81  2024-05-31 00:00:00.000000
# 2         21525.00  2023-01-06 00:00:00.000000
# 3         18493.81  2024-05-14 00:00:00.000000
# 4         17750.00  2024-05-13 00:00:00.000000
# 5         18393.81  2024-05-07 00:00:00.000000
# 6         18393.81  2024-04-30 00:00:00.000000
# 7         18993.81  2024-04-28 00:00:00.000000
# 8         19993.91  2024-04-28 00:00:00.000000
# 9         19150.00  2024-04-20 00:00:00.000000
# 10        20950.00  2024-04-03 00:00:00.000000
# 11        18905.00  2024-03-19 00:00:00.000000
# 12        20993.02  2024-03-30 00:00:00.000000
# 13        18993.81  2024-03-22 00:00:00.000000
# 14        19499.00  2024-03-22 00:00:00.000000
# 15        18593.81  2024-03-20 00:00:00.000000
# 16        18593.81  2024-03-19 00:00:00.000000
# 17        18800.00  2024-03-19 00:00:00.000000
# 18        17000.00  2024-03-17 00:00:00.000000
# 19        18229.55  2024-03-09 00:00:00.000000
#
#                                           listing_url  Size   Reference  \
# 0   https://www.ebay.com/itm/126486174406?hash=ite...    40  126711CHNR
# 1   https://www.ebay.com/itm/186449439850?hash=ite...    40  126711CHNR
# 2   https://www.ebay.com/itm/155065004433?epid=140...    40  126711CHNR
# 3   https://www.ebay.com/itm/156190246811?hash=ite...    40  126711CHNR
# 4   https://www.ebay.com/itm/285852231447?hash=ite...    40  126711CHNR
# 5   https://www.ebay.com/itm/276423187207?hash=ite...    40  126711CHNR
# 6   https://www.ebay.com/itm/305508348292?hash=ite...    40  126711CHNR
# 7   https://www.ebay.com/itm/266766464267?hash=ite...    40  126711CHNR
# 8   https://www.ebay.com/itm/276424263871?hash=ite...    40  126711CHNR
# 9   https://www.ebay.com/itm/135025005846?hash=ite...    40  126711CHNR
# 10  https://www.ebay.com/itm/186290192932?hash=ite...    40  126711CHNR
# 11  https://www.ebay.com/itm/186342568300?hash=ite...    40  126711CHNR
# 12  https://www.ebay.com/itm/276346726913?hash=ite...    40  126711CHNR
# 13  https://www.ebay.com/itm/266729960881?hash=ite...    40  126711CHNR
# 14  https://www.ebay.com/itm/145338143533?hash=ite...    40  126711CHNR
# 15  https://www.ebay.com/itm/305420051266?hash=ite...    40  126711CHNR
# 16  https://www.ebay.com/itm/305409842650?hash=ite...    40  126711CHNR
# 17  https://www.ebay.com/itm/176192745463?hash=ite...    40  126711CHNR
# 18  https://www.ebay.com/itm/116098132712?hash=ite...    40  126711CHNR
# 19  https://www.ebay.com/itm/315186714298?hash=ite...    40  126711CHNR
#
#        Collection    Description  retail_GBP Complication  retail_USD  \
# 0   GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 1   GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 2   GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 3   GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 4   GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 5   GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 6   GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 7   GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 8   GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 9   GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 10  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 11  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 12  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 13  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 14  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 15  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 16  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 17  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 18  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
# 19  GMT-Master II  Standard Dial     14220.0    Date, GMT    18146.14
#
#     profit_USD  growth_pct
# 0      2240.86   12.348962
# 1       247.67    1.364863
# 2      3378.86   18.620269
# 3       347.67    1.915945
# 4      -396.14   -2.183054
# 5       247.67    1.364863
# 6       247.67    1.364863
# 7       847.67    4.671352
# 8      1847.77   10.182717
# 9      1003.86    5.532086
# 10     2803.86   15.451551
# 11      758.86    4.181936
# 12     2846.88   15.688626
# 13      847.67    4.671352
# 14     1352.86    7.455360
# 15      447.67    2.467026
# 16      447.67    2.467026
# 17      653.86    3.603301
# 18    -1146.14   -6.316164
# 19       83.41    0.459657

# %% [markdown]
# ### ***Data exploration***

# %% [markdown]
# ##### *Q1: How much does a brand-new vs. pre-owned Root Beer GMT-Master II go for? How much profit is made?*

# %%
profit_by_cond_query = '''
    SELECT model_number, condition, ROUND(AVG(sold_price_USD), 2) avg_sold_price_USD, retail_USD, ROUND(AVG(profit_USD), 2) avg_profit_USD,
        ROUND(AVG(growth_pct), 2) avg_growth_pct
    FROM df
    GROUP BY condition
    '''

ps.sqldf(profit_by_cond_query, locals())
# Out:
#   model_number  condition  avg_sold_price_USD  retail_USD  avg_profit_USD  \
# 0   126711CHNR  Brand New            20356.85    18146.14         2210.71
# 1   126711CHNR  Pre-Owned            18425.77    18146.14          279.63
#
#    avg_growth_pct
# 0           12.18
# 1            1.54

# %% [markdown]
# ##### *Q2: What is the distribution between brand-new vs. pre-owned listings?*

# %%
count_condition_query = '''
    SELECT model_number, condition, COUNT(title) count
    FROM df
    GROUP BY condition
    '''

ps.sqldf(count_condition_query, locals())
# Out:
#   model_number  condition  count
# 0   126711CHNR  Brand New      7
# 1   126711CHNR  Pre-Owned     13

# %% [markdown]
# ##### *Q3: Which listings were most profitable (separated by condition)?*

# %%
listings_ranked_by_profit_per_cond_query = '''
    SELECT title, model_number, condition, listing_URL, sold_price_USD, retail_USD, profit_USD,
        DENSE_RANK() OVER (PARTITION BY condition ORDER BY profit_USD DESC) ranked_profit_by_cond
    FROM df
    '''

ps.sqldf(listings_ranked_by_profit_per_cond_query, locals())
# Out:
#                                                 title model_number  condition  \
# 0   Rolex GMT-Master II "Root Beer" Automatic Men'...   126711CHNR  Brand New
# 1   NEW FEB 2024 PAPERS Rolex GMT-Master II 18K Go...   126711CHNR  Brand New
# 2   Rolex GMT-Master II 126711CHNR Root Beer UNWOR...   126711CHNR  Brand New
# 3   Rolex GMT-Master II 126711CHNR Root Beer Rose ...   126711CHNR  Brand New
# 4   NEW APRIL 2024 Rolex GMT-Master II Two-Tone Ro...   126711CHNR  Brand New
# 5   2022 Unworn Unsized Rolex GMT Master II Two To...   126711CHNR  Brand New
# 6   Rolex GMT-Master II 126711CHNR Root Beer Unwor...   126711CHNR  Brand New
# 7   2022 PAPERS Rolex GMT-Master II Two-Tone Root ...   126711CHNR  Pre-Owned
# 8   2022 Rolex GMT-Master II Two-Tone ROOT BEER Ro...   126711CHNR  Pre-Owned
# 9   Rolex GMT-Master II Root Beer Wristwatch 12671...   126711CHNR  Pre-Owned
# 10  Rolex GMT-Master II Root Beer 126711CHNR 18k R...   126711CHNR  Pre-Owned
# 11  MINT 2021 PAPERS Rolex GMT-Master II 18K Gold ...   126711CHNR  Pre-Owned
# 12  MINT 2021 PAPERS Rolex GMT-Master II 18K Gold ...   126711CHNR  Pre-Owned
# 13  MINT PAPERS Rolex GMT-Master II Two-Tone Root ...   126711CHNR  Pre-Owned
# 14  Rolex GMT-Master II 126711CHNR Root Beer Two-T...   126711CHNR  Pre-Owned
# 15  MINT 2021 PAPERS Rolex GMT-Master II 18K Gold ...   126711CHNR  Pre-Owned
# 16  MINT 2021 PAPERS Rolex GMT-Master II 18K Gold ...   126711CHNR  Pre-Owned
# 17  ROLEX GMT Master II 126711CHNR Stainless Steel...   126711CHNR  Pre-Owned
# 18  Rolex GMT-Master II Rootbeer Full Set Watch 12...   126711CHNR  Pre-Owned
# 19  Rolex 126711CHNR 40 Mm GMT-Master II Root Beer...   126711CHNR  Pre-Owned
#
#                                           listing_url  sold_price_USD  \
# 0   https://www.ebay.com/itm/155065004433?epid=140...        21525.00
# 1   https://www.ebay.com/itm/276346726913?hash=ite...        20993.02
# 2   https://www.ebay.com/itm/186290192932?hash=ite...        20950.00
# 3   https://www.ebay.com/itm/126486174406?hash=ite...        20387.00
# 4   https://www.ebay.com/itm/276424263871?hash=ite...        19993.91
# 5   https://www.ebay.com/itm/145338143533?hash=ite...        19499.00
# 6   https://www.ebay.com/itm/135025005846?hash=ite...        19150.00
# 7   https://www.ebay.com/itm/266766464267?hash=ite...        18993.81
# 8   https://www.ebay.com/itm/266729960881?hash=ite...        18993.81
# 9   https://www.ebay.com/itm/186342568300?hash=ite...        18905.00
# 10  https://www.ebay.com/itm/176192745463?hash=ite...        18800.00
# 11  https://www.ebay.com/itm/305420051266?hash=ite...        18593.81
# 12  https://www.ebay.com/itm/305409842650?hash=ite...        18593.81
# 13  https://www.ebay.com/itm/156190246811?hash=ite...        18493.81
# 14  https://www.ebay.com/itm/186449439850?hash=ite...        18393.81
# 15  https://www.ebay.com/itm/276423187207?hash=ite...        18393.81
# 16  https://www.ebay.com/itm/305508348292?hash=ite...        18393.81
# 17  https://www.ebay.com/itm/315186714298?hash=ite...        18229.55
# 18  https://www.ebay.com/itm/285852231447?hash=ite...        17750.00
# 19  https://www.ebay.com/itm/116098132712?hash=ite...        17000.00
#
#     retail_USD  profit_USD  ranked_profit_by_cond
# 0     18146.14     3378.86                      1
# 1     18146.14     2846.88                      2
# 2     18146.14     2803.86                      3
# 3     18146.14     2240.86                      4
# 4     18146.14     1847.77                      5
# 5     18146.14     1352.86                      6
# 6     18146.14     1003.86                      7
# 7     18146.14      847.67                      1
# 8     18146.14      847.67                      1
# 9     18146.14      758.86                      2
# 10    18146.14      653.86                      3
# 11    18146.14      447.67                      4
# 12    18146.14      447.67                      4
# 13    18146.14      347.67                      5
# 14    18146.14      247.67                      6
# 15    18146.14      247.67                      6
# 16    18146.14      247.67                      6
# 17    18146.14       83.41                      7
# 18    18146.14     -396.14                      8
# 19    18146.14    -1146.14                      9

# %% [markdown]
# ##### *Q4: What are the monthly averages for sales per condition?*

# %%
monthly_avgs_by_condition_query = '''
    SELECT model_number, condition, strftime('%Y-%m', sold_date) month, ROUND(AVG(sold_price_USD), 2) avg_sold_price_USD, retail_USD, 
        ROUND(AVG(profit_USD), 2) avg_profit_USD
    FROM df
    GROUP BY condition, month
    ORDER BY condition, month DESC
    '''

ps.sqldf(monthly_avgs_by_condition_query, locals())
# Out:
#   model_number  condition    month  avg_sold_price_USD  retail_USD  \
# 0   126711CHNR  Brand New  2024-06            20387.00    18146.14
# 1   126711CHNR  Brand New  2024-04            20031.30    18146.14
# 2   126711CHNR  Brand New  2024-03            20246.01    18146.14
# 3   126711CHNR  Brand New  2023-01            21525.00    18146.14
# 4   126711CHNR  Pre-Owned  2024-05            18257.86    18146.14
# 5   126711CHNR  Pre-Owned  2024-04            18693.81    18146.14
# 6   126711CHNR  Pre-Owned  2024-03            18445.14    18146.14
#
#    avg_profit_USD
# 0         2240.86
# 1         1885.16
# 2         2099.87
# 3         3378.86
# 4          111.72
# 5          547.67
# 6          299.00

# %% [markdown]
# ### ***Saving finalized dataframe as CSV file to library***

# %%
def save_final_csv(final_df,model_number):
    final_df.to_csv('Rolex_' + model_number + '_sold_listings_final.csv', index=False)
    print('Rolex_' + model_number + '_sold_listings_final saved to CSV file')
    return

save_final_csv(df,model_number)
# Out:
# Rolex_126711CHNR_sold_listings_final saved to CSV file
